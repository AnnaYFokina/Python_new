# %% [markdown]
# ## Импорты

# %%
# Библиотека для работы с табличными данными
import pandas as pd

# %%
df3 = pd.read_csv('titanic.csv')

# %% [markdown]
# Будем анализировать информацию про пассажиров "Титаника"

# %%
df3
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %% [markdown]
# Датасет содержит 887 записей, 8 столбцов, без нулевых значений по всем категориям. Типы данных - целочисленное для столбцов с цифровыми значениями, где не может быть дробных значений (например, класс каюты), тип "object" для тестовых значений, тип "float" для цисловых значений, которые могут иметь дробную часть. Для столбца с информацией о том, выжил пассажир или нет, можно было бы вероятно применять тип bool

# %% [markdown]
# В данном случае у нас следующие строки:
#
#
# 1.   **Survived** - пассажир выжил или нет
# 2.   **Pclass** - класс каюты
# 3.   **Name** - имя пассажира
# 4.   **Sex** - пол пассажира
# 5.   **Age** - возраст пассажира
# 6.   **Siblings/Spouses Aboard** - кол-во братьев/сестер/супругов
# 7.   **Parents/Children Aboard** - кол-во родителей/детей
# 8.   **Fare** - стоимость билета

# %%
df3.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# ...

# %% [markdown]
# Получили основные статистические значения по всем столбцам, по которым можно сделать некоторые выводы. Например, классов кают всего 3; часть пассажиров ехали бесплатно; большинство пассажиров младше 40 лет и т.д.

# %% [markdown]
# # Выбор данных

# %%
# Проверим первоначальное предположение, что большинства пассажиров младше 40. Сделаем соответствующую выборку:
df3[df3['Age'] < 40]
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
# 691 пассажир из 887 был младше 40 лет, гипотеза подтвердилась

# %% [markdown]
# Теперь посмотрим гендерное соотношение:

# %%
df3[df3['Sex'] == "male"]
# Out:
#      Survived  Pclass                           Name   Sex   Age  \
# 0           0       3         Mr. Owen Harris Braund  male  22.0
# 4           0       3        Mr. William Henry Allen  male  35.0
# 5           0       3                Mr. James Moran  male  27.0
# 6           0       1         Mr. Timothy J McCarthy  male  54.0
# 7           0       3  Master. Gosta Leonard Palsson  male   2.0
# ..        ...     ...                            ...   ...   ...
# 879         0       2   Mr. Frederick James Banfield  male  28.0
# 880         0       3          Mr. Henry Jr Sutehall  male  25.0
# 882         0       2           Rev. Juozas Montvila  male  27.0
# 885         1       1           Mr. Karl Howell Behr  male  26.0
# 886         0       3             Mr. Patrick Dooley  male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0                          1                        0   7.2500
# ...

# %% [markdown]
# Мужчины составляли примерно 2/3 всех пассажиров, а если точнее, то посчитаем с помощью кода:

# %%
men_to_women = len(df3[df3['Sex'] == "male"]) / len(df3[df3['Sex'] == "female"])

# %%
men_to_women
# Out:
# 1.8248407643312101

# %%
# Сколько выжило несовершеннолетних?
df3[(df3['Age'] < 18) & (df3['Survived'] == 1)]
# Out:
#      Survived  Pclass                                     Name     Sex    Age  \
# 9           1       2       Mrs. Nicholas (Adele Achem) Nasser  female  14.00
# 10          1       3           Miss. Marguerite Rut Sandstrom  female   4.00
# 22          1       3                       Miss. Anna McGowan  female  15.00
# 39          1       3               Miss. Jamila Nicola-Yarred  female  14.00
# 42          1       2  Miss. Simonne Marie Anne Andree Laroche  female   3.00
# ..        ...     ...                                      ...     ...    ...
# 826         1       3   Mrs. Antoni (Selini Alexander) Yasbeck  female  15.00
# 827         1       2           Master. George Sibley Richards    male   0.83
# 849         1       1                 Miss. Mary Conover Lines  female  16.00
# 865         1       3           Master. Harold Theodor Johnson    male   4.00
# 871         1       3                 Miss. Adele Kiamie Najib  female  15.00
#
# ...

# %%
# Сколько погибло несовершеннолетних?
df3[(df3['Age'] < 18) & (df3['Survived'] == 0)]
# Out:
#      Survived  Pclass                                    Name     Sex   Age  \
# 7           0       3           Master. Gosta Leonard Palsson    male   2.0
# 14          0       3     Miss. Hulda Amanda Adolfina Vestrom  female  14.0
# 16          0       3                     Master. Eugene Rice    male   2.0
# 24          0       3            Miss. Torborg Danira Palsson  female   8.0
# 47          0       3                      Mr. Youssef Samaan    male  16.0
# ..        ...     ...                                     ...     ...   ...
# 840         0       3                      Mr. Jeso Culumovic    male  17.0
# 846         0       3  Master. Sigvard Harald Elias Andersson    male   4.0
# 848         0       3                  Miss. Nourelain Boulos  female   9.0
# 859         0       3                Miss. Dorothy Edith Sage  female  14.0
# 884         0       3          Miss. Catherine Helen Johnston  female   7.0
#
# ...

# %% [markdown]
# Удивительно, но количество выживших и погибших детей одинаковое. Причем часть детей - сироты.

# %%
# Медианное значение стоимости билета
df3[['Fare']].median()
# Out:
# Fare    14.4542
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([df3.Fare], [df3.Pclass])
plt.title("Зависимость стоимости билета от класса каюты") # заголовок
plt.xlabel("Стоимость билета") # ось абсцисс
plt.ylabel("Класс каюты") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(x, y)  # построение графика

# %% [markdown]
# Как видно из графика, почти все каюты стоили до 250 у.е. Возможно, каюты за 500 у.е. - это выброс. Эту гипотизу нужно будет проверять при дальнейшем анализе и подготовке данных. Если это так, имеет смысл удалить эти значения из выборки перед созданием моделей.
